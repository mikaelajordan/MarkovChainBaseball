# %% [markdown]
# **Field Visualization**
#
# Goal: using Bokeh, make a passable baseball field diagram drop downs for player positions
#
# This is a decent template: https://upload.wikimedia.org/wikipedia/commons/thumb/6/69/Baseball_fielding_positions_tiny.svg/87px-Baseball_fielding_positions_tiny.svg.png

# %%
from bokeh.io import output_notebook, show
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f7edc037-445e-4dbe-8ec4-b1817af8c606">Loading BokehJS ...</span>
#     </div>

# %%
import pandas as pd
import numpy as np
import math
from bokeh.models import HoverTool, Legend
from bokeh.plotting import figure, show
#from bokeh.models.annotations import Span
from bokeh.models import Range1d, LabelSet, Label


#Set up plot
p = figure(tools=['tap', 'save', 'reset'],
            width=500, height=500, toolbar_location="above")
p.set(x_range=Range1d(-3, 3), y_range=Range1d(-1, 5))
p.axis.visible = False
p.grid.grid_line_alpha = 0.0 

p.wedge(x=0, y=0, radius=3.5, start_angle=45-1.4995, end_angle=135+1.4995,
        color="Green", line_color = "black", alpha = 0.6, #also try or LimeGreen
        start_angle_units="deg", end_angle_units="deg")
p.patch(x=[0,1,0,-1], y=[0,1,2,1], line_color = "black", color="tan")
#p.square(x=0, y=math.sqrt(2), size=50, color="tan", angle = math.pi/4)
#p.annotate()

catcher = Label(x=0, y=0, text=' Catcher ',
                x_offset=0, y_offset=-10, #render_mode='canvas', 
                border_line_color='black',
                background_fill_color='white', 
                text_align = 'center', # options are 'left', 'right', 'center'
                text_baseline = "alphabetic") # options are 'top', 'middle', 'bottom', 'alphabetic', 'hanging' 

pitcher = Label(x=0, y=math.sqrt(2)/2, text=' Pitcher/DH ',
                x_offset=0, y_offset=5, 
                border_line_color='black',
                background_fill_color='white', 
                text_align = 'center', # options are 'left', 'right', 'center'
                text_baseline = "alphabetic") # options are 'top', 'middle', 'bottom', 'alphabetic', 'hanging'

first = Label(x=1, y=1, text=' First Base ',
                x_offset=-15, y_offset=5, #render_mode='canvas', 
                border_line_color='black',
                background_fill_color='white', 
                text_align = 'left', # options are 'left', 'right', 'center'
                text_baseline = "alphabetic") # options are 'top', 'middle', 'bottom', 'alphabetic', 'hanging'

third = Label(x=-1, y=1, text=' Third Base ',
                x_offset=15, y_offset=5, #render_mode='canvas', 
                border_line_color='black',
                background_fill_color='white', 
                text_align = 'right', # options are 'left', 'right', 'center'
                text_baseline = "alphabetic") # options are 'top', 'middle', 'bottom', 'alphabetic', 'hanging'

second = Label(x=0.2, y=1.8, text=' Second Base ',
                x_offset=0, y_offset=0, #render_mode='canvas', 
                border_line_color='black',
                background_fill_color='white', 
                text_align = 'left', # options are 'left', 'right', 'center'
                text_baseline = "alphabetic") # options are 'top', 'middle', 'bottom', 'alphabetic', 'hanging'

shortstop = Label(x=-0.2, y=1.8, text=' Shortstop ',
                x_offset=0, y_offset=0, #render_mode='canvas', 
                border_line_color='black',
                background_fill_color='white', 
                text_align = 'right', # options are 'left', 'right', 'center'
                text_baseline = "alphabetic") # options are 'top', 'middle', 'bottom', 'alphabetic', 'hanging'

lfield = Label(x=-1.5, y=2.5, text=' Left Field ',
                x_offset=0, y_offset=0, #render_mode='canvas', 
                border_line_color='black',
                background_fill_color='white', 
                text_align = 'center', # options are 'left', 'right', 'center'
                text_baseline = "alphabetic") # options are 'top', 'middle', 'bottom', 'alphabetic', 'hanging'

cfield = Label(x=0, y=3, text=' Center Field ',
                x_offset=0, y_offset=0, #render_mode='canvas', 
                border_line_color='black',
                background_fill_color='white', 
                text_align = 'center', # options are 'left', 'right', 'center'
                text_baseline = "alphabetic") # options are 'top', 'middle', 'bottom', 'alphabetic', 'hanging'

rfield = Label(x=1.5, y=2.5, text=' Right Field ',
                x_offset=0, y_offset=0, #render_mode='canvas', 
                border_line_color='black',
                background_fill_color='white', 
                text_align = 'center', # options are 'left', 'right', 'center'
                text_baseline = "alphabetic") # options are 'top', 'middle', 'bottom', 'alphabetic', 'hanging'

p.add_layout(catcher)
p.add_layout(pitcher)
p.add_layout(first)
p.add_layout(second)
p.add_layout(third)
p.add_layout(shortstop)
p.add_layout(lfield)
p.add_layout(cfield)
p.add_layout(rfield)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="7a1146e3-403c-45e2-a228-c9d31875bb38"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7a1146e3-403c-45e2-a228-c9d31875bb38");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7a1146e3-403c-45e2-a228-c9d31875bb38' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"a0443cf9-d58c-4ce2-8361-dec925f06403":{"roots":{"references":[{"attributes":{},"id":"5cec7a9d-7d92-4db0-b6c9-3e7cfa7a7ee0","type":"BasicTickFormatter"},{"attributes":{"fill_color":{"value":"tan"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d04277c7-8c31-4a09-b7a6-025b6722e891","type":"Patch"},{"attributes":{"background_fill_color":{"value":"white"},"border_line_color":{"value":"black"},"plot":{"id":"b60f2f65-cfc0-4e5c-823a-cccef2986ecb","subtype":"Figure","type":"Plot"},"text":" Right Field ","text_align":"center","text_baseline":"alphabetic","x":1.5,"y":2.5},"id":"b5fb258c-4227-4bd5-8413-58f0f59214e1","type":"Label"},{"attributes":{"callback":null},"id":"fb793ee7-9382-4a11-af96-7787ef1450c8","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"593a39ab-53df-4fc6-9e58-2f4c0b81c17e","type":"LinearAxis"}],"left":[{"id":"50142b5e-a827-4712-8cef-b5889a18f2ca","type":"LinearAxis"}],"plot_height":500,"plot_width":500,"renderers":[{"id":"593a39ab-53df-4fc6-9e58-2f4c0b81c17e","type":"LinearAxis"},{"id":"fedd3001-8816-41e6-9ea9-680a9bf83e0d","type":"Grid"},{"id":"50142b5e-a827-4712-8cef-b5889a18f2ca","type":"LinearAxis"},{"id":"d49adab0-d454-498f-8661-0169fe6b83dd","type":"Grid"},{"id":"b46ab91b-26b5-4cd1-877a-5a0be4242ca5","type":"GlyphRenderer"},{"id":"06c27981-69d4-4038-a6bb-ac4bdf6fef4b","type":"GlyphRenderer"},{"id":"5f40d6d8-e32b-4dd1-8c81-c2b7fbd4f4c6","type":"Label"},{"id":"89b791fc-88b7-4347-9a6f-241948e36b3a","type":"Label"},{"id":"2027bdfc-2b71-4bbc-9aca-2026417b82a3","type":"Label"},{"id":"db71ac4d-4b47-4e8e-a3df-42e650adf0e2","type":"Label"},{"id":"67006e01-3671-462d-8f1a-f0aa9995c5e2","type":"Label"},{"id":"2a03286e-fa54-4901-b4f7-6bcf0cf2e2a4","type":"Label"},{"id":"e70e8a77-22ce-4fc9-b0ba-8a0f4c8a24c7","type":"Label"},{"id":"f3288857-2e21-416c-b5fa-b61214e6b0b0","type":"Label"},{"id":"b5fb258c-4227-4bd5-8413-58f0f59214e1","type":"Label"}],"title":{"id":"917f3b46-c9cf-4751-8dac-5e038d9df7c4","type":"Title"},"tool_events":{"id":"c0c5e47c-74ae-4fe3-9013-0c266e431cad","type":"ToolEvents"},"toolbar":{"id":"bab360f6-a881-42bc-9d17-b4e862a897c8","type":"Toolbar"},"toolbar_location":"above","x_range":{"id":"37f8c35f-ee18-4651-aef8-aaac1b4704e0","type":"Range1d"},"y_range":{"id":"f1d5b9f0-b32f-41cf-9f16-63c70b8ef255","type":"Range1d"}},"id":"b60f2f65-cfc0-4e5c-823a-cccef2986ecb","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"end":3,"start":-3},"id":"37f8c35f-ee18-4651-aef8-aaac1b4704e0","type":"Range1d"},{"attributes":{"data_source":{"id":"bbd15378-d288-462a-8d90-efb2b9f5ef81","type":"ColumnDataSource"},"glyph":{"id":"d04277c7-8c31-4a09-b7a6-025b6722e891","type":"Patch"},"hover_glyph":null,"nonselection_glyph":{"id":"a644bae3-9d23-4b91-8a7d-29112e8cc9ea","type":"Patch"},"selection_glyph":null},"id":"06c27981-69d4-4038-a6bb-ac4bdf6fef4b","type":"GlyphRenderer"},{"attributes":{"background_fill_color":{"value":"white"},"border_line_color":{"value":"black"},"plot":{"id":"b60f2f65-cfc0-4e5c-823a-cccef2986ecb","subtype":"Figure","type":"Plot"},"text":" Pitcher/DH ","text_align":"center","text_baseline":"alphabetic","x":0,"y":0.7071067811865476,"y_offset":5},"id":"89b791fc-88b7-4347-9a6f-241948e36b3a","type":"Label"},{"attributes":{"formatter":{"id":"36013e69-f63c-468d-a860-8a483db88363","type":"BasicTickFormatter"},"plot":{"id":"b60f2f65-cfc0-4e5c-823a-cccef2986ecb","subtype":"Figure","type":"Plot"},"ticker":{"id":"79eb65f8-e013-4bc3-90e9-79b651deefa7","type":"BasicTicker"},"visible":false},"id":"50142b5e-a827-4712-8cef-b5889a18f2ca","type":"LinearAxis"},{"attributes":{"end_angle":{"units":"deg","value":136.4995},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":3.5},"start_angle":{"units":"deg","value":43.5005},"x":{"value":0},"y":{"value":0}},"id":"c7419056-baad-4ba1-85c2-4107b7c18efc","type":"Wedge"},{"attributes":{"background_fill_color":{"value":"white"},"border_line_color":{" ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[48]</strong>&gt;</code></p>
